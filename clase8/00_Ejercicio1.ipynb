# %%
import pandas as pd
import urllib.request as url2

# %%
url = "https://datahub.smcgov.org/id/mb6a-xn89.json"

response = url2.urlopen(url)
response

# %%
df = pd.read_json(url)
df
# Out:
#                  geography geography_type                     year  \
# 0                 Atherton           Town  2014-01-01T00:00:00.000
# 1                    Colma           Town  2014-01-01T00:00:00.000
# 2              Foster City           City  2014-01-01T00:00:00.000
# 3           Portola Valley           Town  2014-01-01T00:00:00.000
# 4             Redwood City           City  2014-01-01T00:00:00.000
# 5                   Ladera            CDP  2014-01-01T00:00:00.000
# 6               Moss Beach            CDP  2014-01-01T00:00:00.000
# 7      South San Francisco           City  2014-01-01T00:00:00.000
# 8                  Belmont           City  2014-01-01T00:00:00.000
# 9                Daly City           City  2014-01-01T00:00:00.000
# 10               San Mateo           City  2014-01-01T00:00:00.000
# 11         North Fair Oaks            CDP  2014-01-01T00:00:00.000
# 12      Emerald Lake Hills            CDP  2014-01-01T00:00:00.000
# ...

# %%
df.head(8) #visualizar 8 datos
# Out:
#              geography geography_type                     year  \
# 0             Atherton           Town  2014-01-01T00:00:00.000
# 1                Colma           Town  2014-01-01T00:00:00.000
# 2          Foster City           City  2014-01-01T00:00:00.000
# 3       Portola Valley           Town  2014-01-01T00:00:00.000
# 4         Redwood City           City  2014-01-01T00:00:00.000
# 5               Ladera            CDP  2014-01-01T00:00:00.000
# 6           Moss Beach            CDP  2014-01-01T00:00:00.000
# 7  South San Francisco           City  2014-01-01T00:00:00.000
#
#    less_than_high_school_graduate  high_school_graduate  \
# 0                            13.6                  12.3
# 1                             6.3                   6.4
# 2                            11.9                   9.7
# 3                            48.1                   0.0
# 4                            16.4                  10.6
# 5                             0.0                   0.0
# ...

# %%
#data.info() -> Imprime un resumen consico de un DataFrame: índice columnas
df.info() #muestra resumen de columnas, tipo de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   geography                           32 non-null     object
#  1   geography_type                      32 non-null     object
#  2   year                                32 non-null     object
#  3   less_than_high_school_graduate      32 non-null     float64
#  4   high_school_graduate                32 non-null     float64
#  5   some_college_or_associate_s_degree  32 non-null     float64
#  6   bachelor_s_degree_or_higher         32 non-null     float64
#  7   location_1                          32 non-null     object
#  8   :@computed_region_uph5_8hpn         30 non-null     float64
#  9   :@computed_region_i2t2_cryp         32 non-null     int64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.6+ KB

# %%
#obtener la media, solo de datos float, int, (no objetos)
df.mean()
# Out:
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_8640\534040984.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# less_than_high_school_graduate           17.800000
# high_school_graduate                      6.462500
# some_college_or_associate_s_degree        5.946875
# bachelor_s_degree_or_higher               2.856250
# :@computed_region_uph5_8hpn              17.733333
# :@computed_region_i2t2_cryp           25062.093750
# dtype: float64

# %%
#para obtener la media de una sola columna especifica es utiliza:
df['high_school_graduate'].mean() #media de la columna high school graduate
# Out:
# 6.462500000000001

# %%
#saber el tipo de dato que estamos analizando
type(df) #este objeto es del tipo dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
#saber el numero de columanas y filas
df.shape #(cantidad registros, columnas)
# Out:
# (32, 10)

# %%
#obtener el nombre de las columnas:
df.columns
# Out:
# Index(['geography', 'geography_type', 'year', 'less_than_high_school_graduate',
#        'high_school_graduate', 'some_college_or_associate_s_degree',
#        'bachelor_s_degree_or_higher', 'location_1',
#        ':@computed_region_uph5_8hpn', ':@computed_region_i2t2_cryp'],
#       dtype='object')

# %%
#obtener datos estadisticos como promedio, media, etc
df['high_school_graduate'].describe()
# Out:
# count    32.000000
# mean      6.462500
# std       4.693905
# min       0.000000
# 25%       1.925000
# 50%       7.750000
# 75%       9.450000
# max      16.400000
# Name: high_school_graduate, dtype: float64

# %%
#obtener el valor minimo de una columna especifica
df['high_school_graduate'].min()
# Out:
# 0.0

# %%
#obtener el valor maximo de una columna especifica
df['high_school_graduate'].max()
# Out:
# 16.4

# %%
#obtener la cantidad de registros que tiene la columna especifica
df['high_school_graduate'].count()
# Out:
# 32
