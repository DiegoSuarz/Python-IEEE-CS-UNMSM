# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#importar archivo excel csv
surveys = pd.read_csv("surveys.csv")

# %%
surveys
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
#generar grafica basico
my_plot = surveys.plot("hindfoot_length", 'weight',kind ="scatter") #ejex,ejey,tipo de grafica

# %%
#Grafica del tipo histograma:
sample_data = np.random.normal(0,0.1,1000) #valor minimo, valor maximo, cantidad de datos a generar
sample_data
# Out:
# array([ 1.13378557e-01,  6.46068805e-02, -1.10325470e-01, -8.68306365e-02,
#        -1.78906389e-01, -8.54615786e-02, -1.39037873e-02, -3.77848925e-02,
#         3.02390068e-02,  7.07207778e-02,  6.10336847e-02, -2.43100088e-02,
#         8.29681110e-02,  1.61607479e-01,  1.70521491e-01,  2.62807145e-02,
#         7.49964712e-02,  5.98717825e-02, -9.70045883e-02, -6.46291880e-02,
#        -4.39605465e-02,  9.32575066e-02, -2.31760107e-01, -7.89200533e-02,
#        -1.07394408e-01,  2.17660288e-02,  6.92429939e-02, -1.55752759e-02,
#        -7.04211841e-02,  5.31361825e-02,  5.98757288e-02,  2.88759978e-02,
#        -7.41453289e-02,  9.27498543e-02, -2.51548135e-02,  8.90173927e-02,
#        -2.36150806e-02, -4.22164208e-03,  1.63856265e-02, -1.86003016e-01,
#        -7.91691639e-02,  2.19409401e-02,  1.71691771e-02,  1.10952033e-01,
#         3.71292325e-02, -1.98666336e-01, -4.40909464e-02, -2.00376525e-02,
# ...

# %%
#obteniendo histograma con los datos obtenidos:
plt.hist(sample_data)
plt.show() #se usa para obtener una grafica mas limpia

# %%
#generar un archivo png de la grafica anterior
plt.savefig("histograma.png")

# %%
#
x_values = surveys['year'].unique() #solo toma los valores una ves sin que se repitan
y_values = surveys['year'].value_counts().tolist() #conteo los valores de la columan year

# %%
#obteniendo un grafico de barras.
plt.bar(x_values, y_values)

#para generar un titulo a la imagen
plt.title("Sobrevivientes por año")

#edicion de las etiquetas del ejex y ejey
ax = plt.subplot()
ax.set_xlabel("Año de sobrevivientes")
ax.set_ylabel("Canttidad de sobrevivientes por año")

#Configuracion de colores y tipo de fuente para la grafica:
plt.rcParams['font.family'] = "sans-serif" #cambiar fuente
plt.rcParams["xtick.color"] = "#EF1313"
plt.rcParams["ytick.color"] = "#EF1313"

plt.show() #grafico mas limpio
